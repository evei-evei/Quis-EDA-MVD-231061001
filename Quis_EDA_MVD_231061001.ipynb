# %%
import pandas as pd

# %%
df = pd.read_csv("/content/customer-churn.csv")

# %%
df.head()
# Out:
#    ID  Call Failure Complains  Subscription  Length  Charge Amount  \
# 0   1             3        no                    10              2
# 1   2             8        no                    37              0
# 2   3             0        no                    38              0
# 3   4            10        no                    36              0
# 4   5            10        no                    37              0
#
#    Seconds of Use  Freq. of use  Freq. of SMS  Distinct Called Numbers  \
# 0            1603            25            32                       11
# 1            4255            65             0                       13
# 2               0             0             0                        0
# 3            2338            54           327                       20
# 4            4083            60             0                       31
#
#    Age Group      Plan      Status  Age  Customer Value Churn
# 0          3  pre-paid      active   30         193.120    no
# ...

# %%
len(df)
# Out:
# 3150

# %%
df.tail()
# Out:
#         ID  Call Failure Complains  Subscription  Length  Charge Amount  \
# 3145  3146             0        no                    16              0
# 3146  3147             9        no                    15              0
# 3147  3148             5        no                    13              0
# 3148  3149             1        no                    14              2
# 3149  3150             0        no                     7              0
#
#       Seconds of Use  Freq. of use  Freq. of SMS  Distinct Called Numbers  \
# 3145            1200            19            12                        9
# 3146            5897           134            69                       37
# 3147            8437           164            57                       35
# 3148            2357            38            15                       14
# 3149            3895            33           199                        5
#
#       Age Group       Plan  Status  Age  Customer Value Churn
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3145    False
# 3146    False
# 3147    False
# 3148    False
# 3149    False
# Length: 3150, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3150 non-null   int64
#  1   Call Failure             3150 non-null   int64
#  2   Complains                3150 non-null   object
#  3   Subscription  Length     3150 non-null   int64
#  4   Charge Amount            3150 non-null   int64
#  5   Seconds of Use           3150 non-null   int64
#  6   Freq. of use             3150 non-null   int64
#  7   Freq. of SMS             3150 non-null   int64
#  8   Distinct Called Numbers  3150 non-null   int64
#  9   Age Group                3150 non-null   int64
#  10  Plan                     3150 non-null   object
#  11  Status                   3150 non-null   object
#  12  Age                      3150 non-null   int64
#  13  Customer Value           3150 non-null   float64
# ...

# %%
df['Customer Value'].mean()
# Out:
# 470.9729158730159

# %%
df.isna().sum()
# Out:
# ID                         0
# Call Failure               0
# Complains                  0
# Subscription  Length       0
# Charge Amount              0
# Seconds of Use             0
# Freq. of use               0
# Freq. of SMS               0
# Distinct Called Numbers    0
# Age Group                  0
# Plan                       0
# Status                     0
# Age                        0
# Customer Value             0
# Churn                      0
# dtype: int64

# %%
df = df.rename(columns={'MEDV':'price'})

# %%
df.head()
# Out:
#    ID  Call Failure Complains  Subscription  Length  Charge Amount  \
# 0   1             3        no                    10              2
# 1   2             8        no                    37              0
# 2   3             0        no                    38              0
# 3   4            10        no                    36              0
# 4   5            10        no                    37              0
#
#    Seconds of Use  Freq. of use  Freq. of SMS  Distinct Called Numbers  \
# 0            1603            25            32                       11
# 1            4255            65             0                       13
# 2               0             0             0                        0
# 3            2338            54           327                       20
# 4            4083            60             0                       31
#
#    Age Group      Plan      Status  Age  Customer Value Churn
# 0          3  pre-paid      active   30         193.120    no
# ...

# %%
df.describe()
# Out:
#              ID  Call Failure  Subscription  Length  Charge Amount  \
# count  3150.000   3150.000000           3150.000000    3150.000000
# mean   1575.500      7.627937             32.541905       0.942857
# std     909.471      7.263886              8.573482       1.521072
# min       1.000      0.000000              3.000000       0.000000
# 25%     788.250      1.000000             30.000000       0.000000
# 50%    1575.500      6.000000             35.000000       0.000000
# 75%    2362.750     12.000000             38.000000       1.000000
# max    3150.000     36.000000             47.000000      10.000000
#
#        Seconds of Use  Freq. of use  Freq. of SMS  Distinct Called Numbers  \
# count     3150.000000   3150.000000   3150.000000              3150.000000
# mean      4472.459683     69.460635     73.174921                23.509841
# std       4197.908687     57.413308    112.237560                17.217337
# ...

# %%
import seaborn as sns
sns.boxplot(df['Seconds of Use'])
# Out:
# <Axes: ylabel='Seconds of Use'>

# %%
df['Seconds of Use'].min(), df['Seconds of Use'].max()
# Out:
# (0, 17090)

# %%
sns.displot(df['Freq. of use'], kde= 'hist')

# %%
import numpy as np

df['Freq. of use'] = np.log(df['Freq. of use'])

sns.displot(df['Freq. of use'],kde='hist')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.displot(df['Freq. of SMS'], kde= 'hist')

# %%
import numpy as np

df['Freq. of SMS'] = np.log(df['Freq. of SMS'])

sns.displot(df['Freq. of SMS'],kde='hist')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt # Import the matplotlib.pyplot module

correlation = df.select_dtypes(include=np.number).corr() # Select only numerical columns for correlation calculation

# Visualisasi heatmap korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriks Korelasi Termasuk Churn')
plt.show()
